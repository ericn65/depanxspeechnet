# %% [markdown]
# ## K-FOLD CROSS VALIDATION OVER THE PHQ-8 DL MODEL

# %% [markdown]
# ### Import Libraries

# %%
from sklearn.model_selection import KFold
from data_Loader import dataCreator, dataLoaderPickle, justDatasetLoaderPickle
from networks import FeaturesModel
from networks_v2 import AttentionModel
from optimizer import train2, test2, optimizerNet
from optimizer import IterMeter

import os
import torch
import torch.nn as nn
from comet_ml import Experiment

import matplotlib.pyplot as plt 
import numpy as np

import torch.nn.functional as F 
from sklearn.metrics import confusion_matrix
import seaborn as sn 
import pandas as pd 

from torch.utils.data import Dataset, DataLoader, TensorDataset, random_split, SubsetRandomSampler, ConcatDataset

# %% [markdown]
# ### Loading dataset

# %%
dataset = justDatasetLoaderPickle('BALANCED_DATASET_ENG_SCRIPTED_FULL')

# %% [markdown]
# ### Defining train functions

# %%
def train2(model, device, train_data, criterion, optimizer, scheduler, epochs, iter_meter, experiment):
    acc_list = []
    loss_list = []
    labels_list = []
    predicted_list = []
    loss_tot_list = []
    accuracy = []

    for epoch in range(epochs):
        for x, y in train_data:
            optimizer.zero_grad()
            z = model(x.float())

            labels_list.extend(y.detach().numpy())
            z_pred = F.log_softmax(z, dim=1)
            z_pred = (torch.max(torch.exp(z_pred), 1)[1])
            predicted_list.extend(z_pred.detach().numpy())
            y = y.long()
            #y = y.float()
            z = z.squeeze(0)
            #print("Label size: ", y.size())
            loss = criterion(z, y)
            loss.backward()
            optimizer.step()
            #scheduler.step()
            iter_meter.step()

            loss_list.append(loss.item())
            #Track accuracy
            total = y.size(0)
            _, predicted = torch.max(z.data, 1)
            correct = (predicted == y).sum().item()
            acc_list.append(correct/total)
            
        print('Train Epoch: {} \tLoss: {:.4f}\tAccuracy: {:.4f}'.format(
            epoch,
            np.mean(loss_list),
            np.mean(acc_list)
        ))
        loss_tot_list.append(np.mean(loss_list))
        accuracy.append(np.mean(acc_list))   
    
    #Printing Confusion matrix
    classes = ('0','1','2','3','4')
    cf_matrix = confusion_matrix(labels_list, predicted_list)
    df_cm = pd.DataFrame(cf_matrix/np.sum(cf_matrix)*10, index = [i for i in classes], columns=[i for i in classes])
    plt.figure(figsize=(12,7))
    sn.heatmap(df_cm, annot=True)
    plt.savefig('Confusion Matrix Training')
    
    #Printing training behaviour 
    fig, axs = plt.subplots(2)
    axs[0].plot(range(epochs), loss_tot_list)
    axs[0].set_title('Training Loss')
    axs[0].set(xlabel= 'Epoch',ylabel='Loss')
    axs[1].plot(range(epochs), accuracy)
    axs[1].set_title('Training Accuracy')
    axs[1].set(xlabel= 'Epoch',ylabel='Accuracy')
    plt.show()

# %%
def test2(model, device, test_data, criterion, optimizer, scheduler, epochs, iter_meter, experiment):   
    acc_list = []
    loss_list = []
    labels_list = []
    predicted_list = []
    loss_tot_list = []
    accuracy = []

    for epoch in range(epochs):
        for x, y in test_data:
            optimizer.zero_grad()
            z = model(x.float())
            labels_list.extend(y.detach().numpy())
            z_pred = F.log_softmax(z, dim=1)
            z_pred = (torch.max(torch.exp(z_pred), 1)[1])
            predicted_list.extend(z_pred.detach().numpy())
            y = y.long()
            #y = y.float()
            z = z.squeeze(0)
            #print("Label size: ", y.size())
            loss = criterion(z, y)

            loss.backward()
            optimizer.step()
            #scheduler.step()
            iter_meter.step()

            loss_list.append(loss.item())
            #Track accuracy
            total = y.size(0)
            _, predicted = torch.max(z.data, 1)
            correct = (predicted == y).sum().item()
            acc_list.append(correct/total)
            
        print('Test Epoch: {} \tLoss: {:.4f}\tAccuracy: {:.4f}'.format(
            epoch,
            np.mean(loss_list),
            np.mean(acc_list)
        ))
        loss_tot_list.append(np.mean(loss_list))
        accuracy.append(np.mean(acc_list))    
    
    classes = ('0','1','2','3','4')
    cf_matrix = confusion_matrix(labels_list, predicted_list)
    df_cm = pd.DataFrame(cf_matrix/np.sum(cf_matrix)*10, index = [i for i in classes], columns=[i for i in classes])
    plt.figure(figsize=(12,7))
    sn.heatmap(df_cm, annot=True)
    plt.savefig('Confusion Matrix Test')

    fig, axs = plt.subplots(2)
    axs[0].plot(range(epochs), loss_tot_list)
    axs[0].set_title('Test Loss')
    axs[0].set(xlabel= 'Epoch',ylabel='Loss')
    axs[1].plot(range(epochs), accuracy)
    axs[1].set_title('Test Accuracy')
    axs[1].set(xlabel= 'Epoch',ylabel='Accuracy')
    plt.show()

# %% [markdown]
# ### Defining hyperparameters and main

# %%
#Constants
learning_Rate = 0.0005
batch_size = 128
epochs = 50
k=5
splits=KFold(n_splits=k,shuffle=True,random_state=42)
foldperf={}
experiment = Experiment(api_key='dummy_key', disabled=True)

hparams = {
    "n_cnn_layers": 6,
    "n_rnn_layers": 1,
    "rnn_dim": 256,
    "h_rnn_layers": 128,
    "n_class": 5,
    "n_feats": 64,
    "stride": 2,
    "dropout": 0.3,
    "learning_rate": learning_Rate,
    "batch_size": batch_size,
    "epochs": epochs
}

experiment.log_parameters(hparams)
use_cuda = torch.cuda.is_available()
torch.manual_seed(7)
device = torch.device("cuda" if use_cuda else "cpu")
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.

# %%
#Building and training Model
model = AttentionModel(
    hparams['n_cnn_layers'],
    hparams['rnn_dim'],
    hparams['h_rnn_layers'],
    hparams['n_rnn_layers'],
    hparams['n_class'],
    hparams['stride'],
    hparams['dropout']
).to(device).float()

print(model)
print('Number Model Parameters', sum([param.nelement() for param in model.parameters()]))

#Optimizing Model
optimizer, scheduler = optimizerNet(model, hparams)
weights = [0.95, 0.85, 1.0, 0.9, 1.0]
class_weights = torch.FloatTensor(weights)
criterion = nn.CrossEntropyLoss(weight=class_weights).to(device)
criterion2 = nn.MSELoss()
iter_meter = IterMeter()
# Out:
# AttentionModel(
#   (dense): Conv1d(500, 32, kernel_size=(1,), stride=(1,))
#   (cnn): Sequential(
#     (0): ResCNN(
#       (conv1): Sequential(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#         (2): ReLU()
#       )
#       (conv2): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#       )
#       (relu): ReLU()
#       (dropout): Dropout(p=0.2, inplace=False)
#     )
#     (1): ResCNN(
#       (conv1): Sequential(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#         (2): ReLU()
#       )
#       (conv2): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#       )
#       (relu): ReLU()
#       (dropout): Dropout(p=0.2, inplace=False)
#     )
#     (2): ResCNN(
#       (conv1): Sequential(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#         (2): ReLU()
#       )
#       (conv2): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#       )
#       (relu): ReLU()
#       (dropout): Dropout(p=0.2, inplace=False)
#     )
#     (3): ResCNN(
#       (conv1): Sequential(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#         (2): ReLU()
#       )
#       (conv2): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#       )
#       (relu): ReLU()
#       (dropout): Dropout(p=0.2, inplace=False)
#     )
#     (4): ResCNN(
#       (conv1): Sequential(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#         (2): ReLU()
#       )
#       (conv2): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#       )
#       (relu): ReLU()
#       (dropout): Dropout(p=0.2, inplace=False)
#     )
#     (5): ResCNN(
#       (conv1): Sequential(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#         (2): ReLU()
#       )
#       (conv2): Sequential(
#         (0): Conv1d(32, 32, kernel_size=(1,), stride=(1,))
#       )
#       (relu): ReLU()
#       (dropout): Dropout(p=0.2, inplace=False)
#     )
#   )
#   (dense2): Linear(in_features=1280, out_features=256, bias=True)
#   (lstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#   (atten): MyLSTM(
#     (dropout): Dropout(p=0.2, inplace=False)
#     (lstm1): LSTM(
#       (lstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#     )
#     (atten1): Attention()
#     (lstm2): LSTM(
#       (lstm): LSTM(256, 128, batch_first=True, bidirectional=True)
#     )
#     (atten2): Attention()
#   )
#   (fc): FullyConnected(
#     (fc): Linear(in_features=256, out_features=5, bias=True)
#     (activation): ReLU()
#     (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Number Model Parameters 1545125
# c:\Users\ericq\OneDrive\Escriptori\TELECOM\MSC MATT\TFM\The research question\The Solution\CNN+RNN\networks_v2.py:67: UserWarning: nn.init.uniform is now deprecated in favor of nn.init.uniform_.
#   nn.init.uniform(weight, -stdv, stdv)

# %% [markdown]
# ### K-Fold Cross-Validation

# %%
history = {'Train loss':[], 'Test Loss':[], 'Train Accuracy':[], 'Test Accuracy':[]}

for fold, (train_idx, val_idx) in enumerate(splits.split(np.arange(len(dataset)))):
    print('Fold {}'.format(fold+1))

    train_sampler = SubsetRandomSampler(train_idx)
    test_sampler = SubsetRandomSampler(val_idx)
    train_loader = DataLoader(dataset, batch_size=batch_size, sampler=train_sampler)
    test_loader = DataLoader(dataset, batch_size=batch_size, sampler=test_sampler)

    model = AttentionModel(
        hparams['n_cnn_layers'],
        hparams['rnn_dim'],
        hparams['h_rnn_layers'],
        hparams['n_rnn_layers'],
        hparams['n_class'],
        hparams['stride'],
        hparams['dropout']
    ).to(device).float()
    optimizer, scheduler = optimizerNet(model, hparams)

    train2(model, device, train_loader, criterion, optimizer, scheduler, epochs, iter_meter, experiment)
    test2(model, device, test_loader, criterion, optimizer, scheduler, epochs, iter_meter, experiment)
# Out:
# Fold 1
# Train Epoch: 0 	Loss: 1.5810	Accuracy: 0.2621
# Train Epoch: 1 	Loss: 1.5660	Accuracy: 0.2750
# Train Epoch: 2 	Loss: 1.5577	Accuracy: 0.2804
# Train Epoch: 3 	Loss: 1.5523	Accuracy: 0.2847
# Train Epoch: 4 	Loss: 1.5485	Accuracy: 0.2877
# Train Epoch: 5 	Loss: 1.5454	Accuracy: 0.2905
# Train Epoch: 6 	Loss: 1.5430	Accuracy: 0.2927
# Train Epoch: 7 	Loss: 1.5411	Accuracy: 0.2943
# Train Epoch: 8 	Loss: 1.5393	Accuracy: 0.2960
# Train Epoch: 9 	Loss: 1.5375	Accuracy: 0.2981
# Train Epoch: 10 	Loss: 1.5357	Accuracy: 0.2998
# Train Epoch: 11 	Loss: 1.5344	Accuracy: 0.3014
# Train Epoch: 12 	Loss: 1.5330	Accuracy: 0.3029
# Train Epoch: 13 	Loss: 1.5316	Accuracy: 0.3043
# Train Epoch: 14 	Loss: 1.5301	Accuracy: 0.3059
# Train Epoch: 15 	Loss: 1.5286	Accuracy: 0.3075
# Train Epoch: 16 	Loss: 1.5271	Accuracy: 0.3091
# Train Epoch: 17 	Loss: 1.5257	Accuracy: 0.3105
# Train Epoch: 18 	Loss: 1.5245	Accuracy: 0.3117
# Train Epoch: 19 	Loss: 1.5232	Accuracy: 0.3132
# Train Epoch: 20 	Loss: 1.5219	Accuracy: 0.3144
# Train Epoch: 21 	Loss: 1.5207	Accuracy: 0.3159
# Train Epoch: 22 	Loss: 1.5194	Accuracy: 0.3172
# Train Epoch: 23 	Loss: 1.5181	Accuracy: 0.3187
# Train Epoch: 24 	Loss: 1.5168	Accuracy: 0.3201
# Train Epoch: 25 	Loss: 1.5156	Accuracy: 0.3214
# Train Epoch: 26 	Loss: 1.5132	Accuracy: 0.3224
# Train Epoch: 27 	Loss: 1.5089	Accuracy: 0.3241
# Train Epoch: 28 	Loss: 1.5042	Accuracy: 0.3259
# Train Epoch: 29 	Loss: 1.4993	Accuracy: 0.3282
# Train Epoch: 30 	Loss: 1.4945	Accuracy: 0.3303
# Train Epoch: 31 	Loss: 1.4898	Accuracy: 0.3326
# Train Epoch: 32 	Loss: 1.4851	Accuracy: 0.3347
# Train Epoch: 33 	Loss: 1.4805	Accuracy: 0.3370
# Train Epoch: 34 	Loss: 1.4762	Accuracy: 0.3390
# Train Epoch: 35 	Loss: 1.4719	Accuracy: 0.3411
# Train Epoch: 36 	Loss: 1.4677	Accuracy: 0.3431
# Train Epoch: 37 	Loss: 1.4637	Accuracy: 0.3450
# Train Epoch: 38 	Loss: 1.4598	Accuracy: 0.3469
# Train Epoch: 39 	Loss: 1.4559	Accuracy: 0.3488
# Train Epoch: 40 	Loss: 1.4521	Accuracy: 0.3509
# Train Epoch: 41 	Loss: 1.4483	Accuracy: 0.3529
# Train Epoch: 42 	Loss: 1.4447	Accuracy: 0.3549
# Train Epoch: 43 	Loss: 1.4411	Accuracy: 0.3569
# Train Epoch: 44 	Loss: 1.4376	Accuracy: 0.3589
# Train Epoch: 45 	Loss: 1.4341	Accuracy: 0.3609
# Train Epoch: 46 	Loss: 1.4308	Accuracy: 0.3627
# Train Epoch: 47 	Loss: 1.4275	Accuracy: 0.3645
# Train Epoch: 48 	Loss: 1.4243	Accuracy: 0.3665
# Train Epoch: 49 	Loss: 1.4210	Accuracy: 0.3684
# Test Epoch: 0 	Loss: 1.3662	Accuracy: 0.3361
# Test Epoch: 1 	Loss: 1.3621	Accuracy: 0.3407
# Test Epoch: 2 	Loss: 1.3593	Accuracy: 0.3468
# Test Epoch: 3 	Loss: 1.3574	Accuracy: 0.3516
# Test Epoch: 4 	Loss: 1.3541	Accuracy: 0.3550
# Test Epoch: 5 	Loss: 1.3507	Accuracy: 0.3577
# Test Epoch: 6 	Loss: 1.3483	Accuracy: 0.3600
# Test Epoch: 7 	Loss: 1.3453	Accuracy: 0.3633
# Test Epoch: 8 	Loss: 1.3428	Accuracy: 0.3661
# Test Epoch: 9 	Loss: 1.3402	Accuracy: 0.3694
# Test Epoch: 10 	Loss: 1.3375	Accuracy: 0.3727
# Test Epoch: 11 	Loss: 1.3350	Accuracy: 0.3755
# Test Epoch: 12 	Loss: 1.3326	Accuracy: 0.3777
# Test Epoch: 13 	Loss: 1.3304	Accuracy: 0.3807
# Test Epoch: 14 	Loss: 1.3284	Accuracy: 0.3834
# Test Epoch: 15 	Loss: 1.3265	Accuracy: 0.3858
# Test Epoch: 16 	Loss: 1.3245	Accuracy: 0.3885
# Test Epoch: 17 	Loss: 1.3226	Accuracy: 0.3908
# Test Epoch: 18 	Loss: 1.3204	Accuracy: 0.3932
# Test Epoch: 19 	Loss: 1.3185	Accuracy: 0.3954
# Test Epoch: 20 	Loss: 1.3164	Accuracy: 0.3976
# Test Epoch: 21 	Loss: 1.3142	Accuracy: 0.3999
# Test Epoch: 22 	Loss: 1.3122	Accuracy: 0.4023
# Test Epoch: 23 	Loss: 1.3099	Accuracy: 0.4047
# Test Epoch: 24 	Loss: 1.3080	Accuracy: 0.4068
# Test Epoch: 25 	Loss: 1.3061	Accuracy: 0.4091
# Test Epoch: 26 	Loss: 1.3043	Accuracy: 0.4112
# Test Epoch: 27 	Loss: 1.3023	Accuracy: 0.4133
# Test Epoch: 28 	Loss: 1.3005	Accuracy: 0.4154
# Test Epoch: 29 	Loss: 1.2989	Accuracy: 0.4172
# Test Epoch: 30 	Loss: 1.2971	Accuracy: 0.4191
# Test Epoch: 31 	Loss: 1.2954	Accuracy: 0.4211
# Test Epoch: 32 	Loss: 1.2937	Accuracy: 0.4232
# Test Epoch: 33 	Loss: 1.2918	Accuracy: 0.4254
# Test Epoch: 34 	Loss: 1.2900	Accuracy: 0.4274
# Test Epoch: 35 	Loss: 1.2884	Accuracy: 0.4292
# Test Epoch: 36 	Loss: 1.2867	Accuracy: 0.4310
# Test Epoch: 37 	Loss: 1.2849	Accuracy: 0.4331
# Test Epoch: 38 	Loss: 1.2832	Accuracy: 0.4350
# Test Epoch: 39 	Loss: 1.2813	Accuracy: 0.4370
# Test Epoch: 40 	Loss: 1.2794	Accuracy: 0.4391
# Test Epoch: 41 	Loss: 1.2776	Accuracy: 0.4409
# Test Epoch: 42 	Loss: 1.2759	Accuracy: 0.4430
# Test Epoch: 43 	Loss: 1.2743	Accuracy: 0.4448
# Test Epoch: 44 	Loss: 1.2726	Accuracy: 0.4468
# Test Epoch: 45 	Loss: 1.2708	Accuracy: 0.4488
# Test Epoch: 46 	Loss: 1.2690	Accuracy: 0.4504
# Test Epoch: 47 	Loss: 1.2673	Accuracy: 0.4523
# Test Epoch: 48 	Loss: 1.2656	Accuracy: 0.4542
# Test Epoch: 49 	Loss: 1.2638	Accuracy: 0.4560
# Fold 2
# c:\Users\ericq\OneDrive\Escriptori\TELECOM\MSC MATT\TFM\The research question\The Solution\CNN+RNN\networks_v2.py:67: UserWarning: nn.init.uniform is now deprecated in favor of nn.init.uniform_.
#   nn.init.uniform(weight, -stdv, stdv)
# Train Epoch: 0 	Loss: 1.5931	Accuracy: 0.2917
# Train Epoch: 1 	Loss: 1.5694	Accuracy: 0.3095
# Train Epoch: 2 	Loss: 1.5529	Accuracy: 0.3156
# Train Epoch: 3 	Loss: 1.5372	Accuracy: 0.3169
# Train Epoch: 4 	Loss: 1.5245	Accuracy: 0.3193
# Train Epoch: 5 	Loss: 1.5141	Accuracy: 0.3211
# Train Epoch: 6 	Loss: 1.5056	Accuracy: 0.3229
# Train Epoch: 7 	Loss: 1.4987	Accuracy: 0.3248
# Train Epoch: 8 	Loss: 1.4929	Accuracy: 0.3266
# Train Epoch: 9 	Loss: 1.4877	Accuracy: 0.3282
# Train Epoch: 10 	Loss: 1.4833	Accuracy: 0.3297
# Train Epoch: 11 	Loss: 1.4792	Accuracy: 0.3304
# Train Epoch: 12 	Loss: 1.4739	Accuracy: 0.3312
# Train Epoch: 13 	Loss: 1.4687	Accuracy: 0.3320
# Train Epoch: 14 	Loss: 1.4638	Accuracy: 0.3332
# Train Epoch: 15 	Loss: 1.4592	Accuracy: 0.3348
# Train Epoch: 16 	Loss: 1.4549	Accuracy: 0.3356
# Train Epoch: 17 	Loss: 1.4510	Accuracy: 0.3367
# Train Epoch: 18 	Loss: 1.4474	Accuracy: 0.3375
# Train Epoch: 19 	Loss: 1.4440	Accuracy: 0.3388
# Train Epoch: 20 	Loss: 1.4409	Accuracy: 0.3398
# Train Epoch: 21 	Loss: 1.4379	Accuracy: 0.3411
# Train Epoch: 22 	Loss: 1.4350	Accuracy: 0.3423
# Train Epoch: 23 	Loss: 1.4323	Accuracy: 0.3433
# Train Epoch: 24 	Loss: 1.4297	Accuracy: 0.3445
# Train Epoch: 25 	Loss: 1.4271	Accuracy: 0.3457
# Train Epoch: 26 	Loss: 1.4246	Accuracy: 0.3469
# Train Epoch: 27 	Loss: 1.4222	Accuracy: 0.3481
# Train Epoch: 28 	Loss: 1.4198	Accuracy: 0.3493
# Train Epoch: 29 	Loss: 1.4176	Accuracy: 0.3504
# Train Epoch: 30 	Loss: 1.4154	Accuracy: 0.3515
# Train Epoch: 31 	Loss: 1.4133	Accuracy: 0.3527
# Train Epoch: 32 	Loss: 1.4111	Accuracy: 0.3540
# Train Epoch: 33 	Loss: 1.4091	Accuracy: 0.3550
# Train Epoch: 34 	Loss: 1.4071	Accuracy: 0.3562
# Train Epoch: 35 	Loss: 1.4051	Accuracy: 0.3572
# Train Epoch: 36 	Loss: 1.4032	Accuracy: 0.3585
# Train Epoch: 37 	Loss: 1.4013	Accuracy: 0.3596
# Train Epoch: 38 	Loss: 1.3995	Accuracy: 0.3608
# Train Epoch: 39 	Loss: 1.3976	Accuracy: 0.3620
# Train Epoch: 40 	Loss: 1.3958	Accuracy: 0.3631
# Train Epoch: 41 	Loss: 1.3940	Accuracy: 0.3642
# Train Epoch: 42 	Loss: 1.3922	Accuracy: 0.3653
# Train Epoch: 43 	Loss: 1.3905	Accuracy: 0.3664
# Train Epoch: 44 	Loss: 1.3888	Accuracy: 0.3675
# Train Epoch: 45 	Loss: 1.3871	Accuracy: 0.3686
# Train Epoch: 46 	Loss: 1.3854	Accuracy: 0.3698
# Train Epoch: 47 	Loss: 1.3838	Accuracy: 0.3709
# Train Epoch: 48 	Loss: 1.3821	Accuracy: 0.3719
# Train Epoch: 49 	Loss: 1.3805	Accuracy: 0.3729
# Test Epoch: 0 	Loss: 1.3391	Accuracy: 0.3591
# Test Epoch: 1 	Loss: 1.3369	Accuracy: 0.3643
# Test Epoch: 2 	Loss: 1.3332	Accuracy: 0.3697
# Test Epoch: 3 	Loss: 1.3296	Accuracy: 0.3722
# Test Epoch: 4 	Loss: 1.3275	Accuracy: 0.3739
# Test Epoch: 5 	Loss: 1.3251	Accuracy: 0.3777
# Test Epoch: 6 	Loss: 1.3239	Accuracy: 0.3809
# Test Epoch: 7 	Loss: 1.3221	Accuracy: 0.3830
# Test Epoch: 8 	Loss: 1.3200	Accuracy: 0.3854
# Test Epoch: 9 	Loss: 1.3184	Accuracy: 0.3877
# Test Epoch: 10 	Loss: 1.3167	Accuracy: 0.3898
# Test Epoch: 11 	Loss: 1.3151	Accuracy: 0.3921
# Test Epoch: 12 	Loss: 1.3135	Accuracy: 0.3940
# Test Epoch: 13 	Loss: 1.3117	Accuracy: 0.3965
# Test Epoch: 14 	Loss: 1.3102	Accuracy: 0.3988
# Test Epoch: 15 	Loss: 1.3086	Accuracy: 0.4007
# Test Epoch: 16 	Loss: 1.3071	Accuracy: 0.4024
# Test Epoch: 17 	Loss: 1.3056	Accuracy: 0.4045
# Test Epoch: 18 	Loss: 1.3039	Accuracy: 0.4063
# Test Epoch: 19 	Loss: 1.3021	Accuracy: 0.4088
# Test Epoch: 20 	Loss: 1.3007	Accuracy: 0.4105
# Test Epoch: 21 	Loss: 1.2990	Accuracy: 0.4123
# Test Epoch: 22 	Loss: 1.2974	Accuracy: 0.4143
# Test Epoch: 23 	Loss: 1.2960	Accuracy: 0.4159
# Test Epoch: 24 	Loss: 1.2945	Accuracy: 0.4175
# Test Epoch: 25 	Loss: 1.2930	Accuracy: 0.4191
# Test Epoch: 26 	Loss: 1.2917	Accuracy: 0.4206
# Test Epoch: 27 	Loss: 1.2901	Accuracy: 0.4225
# Test Epoch: 28 	Loss: 1.2886	Accuracy: 0.4244
# Test Epoch: 29 	Loss: 1.2872	Accuracy: 0.4262
# Test Epoch: 30 	Loss: 1.2860	Accuracy: 0.4274
# Test Epoch: 31 	Loss: 1.2847	Accuracy: 0.4287
# Test Epoch: 32 	Loss: 1.2833	Accuracy: 0.4303
# Test Epoch: 33 	Loss: 1.2821	Accuracy: 0.4319
# Test Epoch: 34 	Loss: 1.2809	Accuracy: 0.4332
# Test Epoch: 35 	Loss: 1.2794	Accuracy: 0.4350
# Test Epoch: 36 	Loss: 1.2779	Accuracy: 0.4365
# Test Epoch: 37 	Loss: 1.2764	Accuracy: 0.4381
# Test Epoch: 38 	Loss: 1.2749	Accuracy: 0.4397
# Test Epoch: 39 	Loss: 1.2735	Accuracy: 0.4410
# Test Epoch: 40 	Loss: 1.2721	Accuracy: 0.4426
# Test Epoch: 41 	Loss: 1.2707	Accuracy: 0.4440
# Test Epoch: 42 	Loss: 1.2693	Accuracy: 0.4455
# Test Epoch: 43 	Loss: 1.2679	Accuracy: 0.4471
# Test Epoch: 44 	Loss: 1.2665	Accuracy: 0.4486
# Test Epoch: 45 	Loss: 1.2652	Accuracy: 0.4500
# Test Epoch: 46 	Loss: 1.2638	Accuracy: 0.4515
# Test Epoch: 47 	Loss: 1.2624	Accuracy: 0.4529
# Test Epoch: 48 	Loss: 1.2609	Accuracy: 0.4544
# Test Epoch: 49 	Loss: 1.2593	Accuracy: 0.4560
# Fold 3
# c:\Users\ericq\OneDrive\Escriptori\TELECOM\MSC MATT\TFM\The research question\The Solution\CNN+RNN\networks_v2.py:67: UserWarning: nn.init.uniform is now deprecated in favor of nn.init.uniform_.
#   nn.init.uniform(weight, -stdv, stdv)
# Train Epoch: 0 	Loss: 1.6004	Accuracy: 0.2328
# Train Epoch: 1 	Loss: 1.5968	Accuracy: 0.2407
# Train Epoch: 2 	Loss: 1.5948	Accuracy: 0.2441
# Train Epoch: 3 	Loss: 1.5921	Accuracy: 0.2463
# Train Epoch: 4 	Loss: 1.5862	Accuracy: 0.2519
# Train Epoch: 5 	Loss: 1.5812	Accuracy: 0.2566
# Train Epoch: 6 	Loss: 1.5771	Accuracy: 0.2603
# Train Epoch: 7 	Loss: 1.5689	Accuracy: 0.2675
# Train Epoch: 8 	Loss: 1.5612	Accuracy: 0.2747
# Train Epoch: 9 	Loss: 1.5546	Accuracy: 0.2806
# Train Epoch: 10 	Loss: 1.5491	Accuracy: 0.2857
# Train Epoch: 11 	Loss: 1.5444	Accuracy: 0.2898
# Train Epoch: 12 	Loss: 1.5402	Accuracy: 0.2937
# Train Epoch: 13 	Loss: 1.5363	Accuracy: 0.2971
# Train Epoch: 14 	Loss: 1.5327	Accuracy: 0.3005
# Train Epoch: 15 	Loss: 1.5293	Accuracy: 0.3043
# Train Epoch: 16 	Loss: 1.5262	Accuracy: 0.3076
# Train Epoch: 17 	Loss: 1.5232	Accuracy: 0.3109
# Train Epoch: 18 	Loss: 1.5203	Accuracy: 0.3141
# Train Epoch: 19 	Loss: 1.5178	Accuracy: 0.3169
# Train Epoch: 20 	Loss: 1.5152	Accuracy: 0.3198
# Train Epoch: 21 	Loss: 1.5128	Accuracy: 0.3223
# Train Epoch: 22 	Loss: 1.5104	Accuracy: 0.3254
# Train Epoch: 23 	Loss: 1.5082	Accuracy: 0.3280
# Train Epoch: 24 	Loss: 1.5059	Accuracy: 0.3306
# Train Epoch: 25 	Loss: 1.5036	Accuracy: 0.3332
# Train Epoch: 26 	Loss: 1.5015	Accuracy: 0.3355
# Train Epoch: 27 	Loss: 1.4992	Accuracy: 0.3381
# Train Epoch: 28 	Loss: 1.4972	Accuracy: 0.3405
# Train Epoch: 29 	Loss: 1.4952	Accuracy: 0.3428
# Train Epoch: 30 	Loss: 1.4931	Accuracy: 0.3450
# Train Epoch: 31 	Loss: 1.4912	Accuracy: 0.3472
# Train Epoch: 32 	Loss: 1.4892	Accuracy: 0.3495
# Train Epoch: 33 	Loss: 1.4872	Accuracy: 0.3517
# Train Epoch: 34 	Loss: 1.4853	Accuracy: 0.3539
# Train Epoch: 35 	Loss: 1.4833	Accuracy: 0.3562
# Train Epoch: 36 	Loss: 1.4815	Accuracy: 0.3583
# Train Epoch: 37 	Loss: 1.4796	Accuracy: 0.3603
# Train Epoch: 38 	Loss: 1.4777	Accuracy: 0.3624
# Train Epoch: 39 	Loss: 1.4757	Accuracy: 0.3642
# Train Epoch: 40 	Loss: 1.4738	Accuracy: 0.3663
# Train Epoch: 41 	Loss: 1.4720	Accuracy: 0.3683
# Train Epoch: 42 	Loss: 1.4700	Accuracy: 0.3703
# Train Epoch: 43 	Loss: 1.4681	Accuracy: 0.3722
# Train Epoch: 44 	Loss: 1.4662	Accuracy: 0.3739
# Train Epoch: 45 	Loss: 1.4644	Accuracy: 0.3759
# Train Epoch: 46 	Loss: 1.4625	Accuracy: 0.3776
# Train Epoch: 47 	Loss: 1.4607	Accuracy: 0.3794
# Train Epoch: 48 	Loss: 1.4588	Accuracy: 0.3812
# Train Epoch: 49 	Loss: 1.4569	Accuracy: 0.3830
# Test Epoch: 0 	Loss: 1.4573	Accuracy: 0.3666
# Test Epoch: 1 	Loss: 1.4445	Accuracy: 0.3720
# Test Epoch: 2 	Loss: 1.4310	Accuracy: 0.3760
# Test Epoch: 3 	Loss: 1.4177	Accuracy: 0.3803
# Test Epoch: 4 	Loss: 1.4069	Accuracy: 0.3838
# Test Epoch: 5 	Loss: 1.3978	Accuracy: 0.3880
# Test Epoch: 6 	Loss: 1.3896	Accuracy: 0.3916
# Test Epoch: 7 	Loss: 1.3830	Accuracy: 0.3939
# Test Epoch: 8 	Loss: 1.3772	Accuracy: 0.3962
# Test Epoch: 9 	Loss: 1.3723	Accuracy: 0.3985
# Test Epoch: 10 	Loss: 1.3672	Accuracy: 0.4018
# Test Epoch: 11 	Loss: 1.3623	Accuracy: 0.4046
# Test Epoch: 12 	Loss: 1.3576	Accuracy: 0.4077
# Test Epoch: 13 	Loss: 1.3535	Accuracy: 0.4103
# Test Epoch: 14 	Loss: 1.3493	Accuracy: 0.4132
# Test Epoch: 15 	Loss: 1.3454	Accuracy: 0.4163
# Test Epoch: 16 	Loss: 1.3417	Accuracy: 0.4190
# Test Epoch: 17 	Loss: 1.3381	Accuracy: 0.4221
# Test Epoch: 18 	Loss: 1.3345	Accuracy: 0.4246
# Test Epoch: 19 	Loss: 1.3313	Accuracy: 0.4269
# Test Epoch: 20 	Loss: 1.3280	Accuracy: 0.4295
# Test Epoch: 21 	Loss: 1.3248	Accuracy: 0.4321
# Test Epoch: 22 	Loss: 1.3215	Accuracy: 0.4346
# Test Epoch: 23 	Loss: 1.3182	Accuracy: 0.4372
# Test Epoch: 24 	Loss: 1.3150	Accuracy: 0.4394
# Test Epoch: 25 	Loss: 1.3124	Accuracy: 0.4413
# Test Epoch: 26 	Loss: 1.3096	Accuracy: 0.4434
# Test Epoch: 27 	Loss: 1.3069	Accuracy: 0.4456
# Test Epoch: 28 	Loss: 1.3041	Accuracy: 0.4479
# Test Epoch: 29 	Loss: 1.3015	Accuracy: 0.4501
# Test Epoch: 30 	Loss: 1.2986	Accuracy: 0.4525
# Test Epoch: 31 	Loss: 1.2959	Accuracy: 0.4548
# Test Epoch: 32 	Loss: 1.2934	Accuracy: 0.4570
# Test Epoch: 33 	Loss: 1.2907	Accuracy: 0.4594
# Test Epoch: 34 	Loss: 1.2879	Accuracy: 0.4615
# Test Epoch: 35 	Loss: 1.2853	Accuracy: 0.4636
# Test Epoch: 36 	Loss: 1.2828	Accuracy: 0.4657
# Test Epoch: 37 	Loss: 1.2802	Accuracy: 0.4678
# Test Epoch: 38 	Loss: 1.2777	Accuracy: 0.4696
# Test Epoch: 39 	Loss: 1.2754	Accuracy: 0.4714
# Test Epoch: 40 	Loss: 1.2731	Accuracy: 0.4734
# Test Epoch: 41 	Loss: 1.2709	Accuracy: 0.4749
# Test Epoch: 42 	Loss: 1.2685	Accuracy: 0.4770
# Test Epoch: 43 	Loss: 1.2662	Accuracy: 0.4790
# Test Epoch: 44 	Loss: 1.2636	Accuracy: 0.4810
# Test Epoch: 45 	Loss: 1.2613	Accuracy: 0.4829
# Test Epoch: 46 	Loss: 1.2589	Accuracy: 0.4848
# Test Epoch: 47 	Loss: 1.2566	Accuracy: 0.4867
# Test Epoch: 48 	Loss: 1.2541	Accuracy: 0.4887
# Test Epoch: 49 	Loss: 1.2519	Accuracy: 0.4906
# Fold 4
# c:\Users\ericq\OneDrive\Escriptori\TELECOM\MSC MATT\TFM\The research question\The Solution\CNN+RNN\networks_v2.py:67: UserWarning: nn.init.uniform is now deprecated in favor of nn.init.uniform_.
#   nn.init.uniform(weight, -stdv, stdv)
# Train Epoch: 0 	Loss: 1.6037	Accuracy: 0.2301
# Train Epoch: 1 	Loss: 1.5934	Accuracy: 0.2443
# Train Epoch: 2 	Loss: 1.5791	Accuracy: 0.2602
# Train Epoch: 3 	Loss: 1.5696	Accuracy: 0.2710
# Train Epoch: 4 	Loss: 1.5516	Accuracy: 0.2802
# Train Epoch: 5 	Loss: 1.5332	Accuracy: 0.2876
# Train Epoch: 6 	Loss: 1.5181	Accuracy: 0.2941
# Train Epoch: 7 	Loss: 1.5060	Accuracy: 0.2980
# Train Epoch: 8 	Loss: 1.4959	Accuracy: 0.3021
# Train Epoch: 9 	Loss: 1.4875	Accuracy: 0.3059
# Train Epoch: 10 	Loss: 1.4800	Accuracy: 0.3093
# Train Epoch: 11 	Loss: 1.4736	Accuracy: 0.3120
# Train Epoch: 12 	Loss: 1.4678	Accuracy: 0.3142
# Train Epoch: 13 	Loss: 1.4627	Accuracy: 0.3162
# Train Epoch: 14 	Loss: 1.4581	Accuracy: 0.3182
# Train Epoch: 15 	Loss: 1.4539	Accuracy: 0.3200
# Train Epoch: 16 	Loss: 1.4499	Accuracy: 0.3220
# Train Epoch: 17 	Loss: 1.4461	Accuracy: 0.3237
# Train Epoch: 18 	Loss: 1.4426	Accuracy: 0.3254
# Train Epoch: 19 	Loss: 1.4393	Accuracy: 0.3270
# Train Epoch: 20 	Loss: 1.4361	Accuracy: 0.3285
# Train Epoch: 21 	Loss: 1.4332	Accuracy: 0.3299
# Train Epoch: 22 	Loss: 1.4303	Accuracy: 0.3316
# Train Epoch: 23 	Loss: 1.4276	Accuracy: 0.3331
# Train Epoch: 24 	Loss: 1.4251	Accuracy: 0.3345
# Train Epoch: 25 	Loss: 1.4226	Accuracy: 0.3360
# Train Epoch: 26 	Loss: 1.4202	Accuracy: 0.3374
# Train Epoch: 27 	Loss: 1.4179	Accuracy: 0.3389
# Train Epoch: 28 	Loss: 1.4156	Accuracy: 0.3403
# Train Epoch: 29 	Loss: 1.4133	Accuracy: 0.3419
# Train Epoch: 30 	Loss: 1.4113	Accuracy: 0.3432
# Train Epoch: 31 	Loss: 1.4092	Accuracy: 0.3447
# Train Epoch: 32 	Loss: 1.4071	Accuracy: 0.3463
# Train Epoch: 33 	Loss: 1.4050	Accuracy: 0.3479
# Train Epoch: 34 	Loss: 1.4030	Accuracy: 0.3494
# Train Epoch: 35 	Loss: 1.4012	Accuracy: 0.3507
# Train Epoch: 36 	Loss: 1.3993	Accuracy: 0.3521
# Train Epoch: 37 	Loss: 1.3974	Accuracy: 0.3535
# Train Epoch: 38 	Loss: 1.3955	Accuracy: 0.3548
# Train Epoch: 39 	Loss: 1.3938	Accuracy: 0.3563
# Train Epoch: 40 	Loss: 1.3920	Accuracy: 0.3575
# Train Epoch: 41 	Loss: 1.3902	Accuracy: 0.3587
# Train Epoch: 42 	Loss: 1.3884	Accuracy: 0.3602
# Train Epoch: 43 	Loss: 1.3866	Accuracy: 0.3617
# Train Epoch: 44 	Loss: 1.3848	Accuracy: 0.3630
# Train Epoch: 45 	Loss: 1.3831	Accuracy: 0.3643
# Train Epoch: 46 	Loss: 1.3814	Accuracy: 0.3657
# Train Epoch: 47 	Loss: 1.3797	Accuracy: 0.3669
# Train Epoch: 48 	Loss: 1.3779	Accuracy: 0.3683
# Train Epoch: 49 	Loss: 1.3762	Accuracy: 0.3696
# Test Epoch: 0 	Loss: 1.3700	Accuracy: 0.3436
# Test Epoch: 1 	Loss: 1.3640	Accuracy: 0.3560
# Test Epoch: 2 	Loss: 1.3604	Accuracy: 0.3612
# Test Epoch: 3 	Loss: 1.3568	Accuracy: 0.3666
# Test Epoch: 4 	Loss: 1.3535	Accuracy: 0.3720
# Test Epoch: 5 	Loss: 1.3510	Accuracy: 0.3753
# Test Epoch: 6 	Loss: 1.3489	Accuracy: 0.3770
# Test Epoch: 7 	Loss: 1.3464	Accuracy: 0.3798
# Test Epoch: 8 	Loss: 1.3446	Accuracy: 0.3818
# Test Epoch: 9 	Loss: 1.3434	Accuracy: 0.3842
# Test Epoch: 10 	Loss: 1.3419	Accuracy: 0.3855
# Test Epoch: 11 	Loss: 1.3404	Accuracy: 0.3877
# Test Epoch: 12 	Loss: 1.3388	Accuracy: 0.3895
# Test Epoch: 13 	Loss: 1.3371	Accuracy: 0.3914
# Test Epoch: 14 	Loss: 1.3357	Accuracy: 0.3926
# Test Epoch: 15 	Loss: 1.3343	Accuracy: 0.3944
# Test Epoch: 16 	Loss: 1.3332	Accuracy: 0.3955
# Test Epoch: 17 	Loss: 1.3320	Accuracy: 0.3970
# Test Epoch: 18 	Loss: 1.3304	Accuracy: 0.3989
# Test Epoch: 19 	Loss: 1.3290	Accuracy: 0.4007
# Test Epoch: 20 	Loss: 1.3278	Accuracy: 0.4018
# Test Epoch: 21 	Loss: 1.3265	Accuracy: 0.4037
# Test Epoch: 22 	Loss: 1.3252	Accuracy: 0.4054
# Test Epoch: 23 	Loss: 1.3240	Accuracy: 0.4069
# Test Epoch: 24 	Loss: 1.3227	Accuracy: 0.4081
# Test Epoch: 25 	Loss: 1.3212	Accuracy: 0.4099
# Test Epoch: 26 	Loss: 1.3199	Accuracy: 0.4114
# Test Epoch: 27 	Loss: 1.3187	Accuracy: 0.4128
# Test Epoch: 28 	Loss: 1.3176	Accuracy: 0.4142
# Test Epoch: 29 	Loss: 1.3165	Accuracy: 0.4156
# Test Epoch: 30 	Loss: 1.3154	Accuracy: 0.4171
# Test Epoch: 31 	Loss: 1.3143	Accuracy: 0.4183
# Test Epoch: 32 	Loss: 1.3131	Accuracy: 0.4198
# Test Epoch: 33 	Loss: 1.3117	Accuracy: 0.4212
# Test Epoch: 34 	Loss: 1.3104	Accuracy: 0.4228
# Test Epoch: 35 	Loss: 1.3093	Accuracy: 0.4239
# Test Epoch: 36 	Loss: 1.3079	Accuracy: 0.4253
# Test Epoch: 37 	Loss: 1.3064	Accuracy: 0.4267
# Test Epoch: 38 	Loss: 1.3051	Accuracy: 0.4280
# Test Epoch: 39 	Loss: 1.3038	Accuracy: 0.4293
# Test Epoch: 40 	Loss: 1.3025	Accuracy: 0.4307
# Test Epoch: 41 	Loss: 1.3012	Accuracy: 0.4322
# Test Epoch: 42 	Loss: 1.2999	Accuracy: 0.4336
# Test Epoch: 43 	Loss: 1.2987	Accuracy: 0.4349
# Test Epoch: 44 	Loss: 1.2974	Accuracy: 0.4363
# Test Epoch: 45 	Loss: 1.2962	Accuracy: 0.4377
# Test Epoch: 46 	Loss: 1.2950	Accuracy: 0.4390
# Test Epoch: 47 	Loss: 1.2938	Accuracy: 0.4401
# Test Epoch: 48 	Loss: 1.2925	Accuracy: 0.4414
# Test Epoch: 49 	Loss: 1.2911	Accuracy: 0.4429
# Fold 5
# c:\Users\ericq\OneDrive\Escriptori\TELECOM\MSC MATT\TFM\The research question\The Solution\CNN+RNN\networks_v2.py:67: UserWarning: nn.init.uniform is now deprecated in favor of nn.init.uniform_.
#   nn.init.uniform(weight, -stdv, stdv)
# Train Epoch: 0 	Loss: 1.5710	Accuracy: 0.2485
# Train Epoch: 1 	Loss: 1.5446	Accuracy: 0.2680
# Train Epoch: 2 	Loss: 1.5270	Accuracy: 0.2832
# Train Epoch: 3 	Loss: 1.5154	Accuracy: 0.2906
# Train Epoch: 4 	Loss: 1.5061	Accuracy: 0.2961
# Train Epoch: 5 	Loss: 1.4981	Accuracy: 0.3021
# Train Epoch: 6 	Loss: 1.4917	Accuracy: 0.3065
# Train Epoch: 7 	Loss: 1.4864	Accuracy: 0.3102
# Train Epoch: 8 	Loss: 1.4818	Accuracy: 0.3133
# Train Epoch: 9 	Loss: 1.4778	Accuracy: 0.3160
# Train Epoch: 10 	Loss: 1.4742	Accuracy: 0.3182
# Train Epoch: 11 	Loss: 1.4709	Accuracy: 0.3203
# Train Epoch: 12 	Loss: 1.4680	Accuracy: 0.3220
# Train Epoch: 13 	Loss: 1.4654	Accuracy: 0.3237
# Train Epoch: 14 	Loss: 1.4630	Accuracy: 0.3250
# Train Epoch: 15 	Loss: 1.4609	Accuracy: 0.3263
# Train Epoch: 16 	Loss: 1.4589	Accuracy: 0.3274
# Train Epoch: 17 	Loss: 1.4570	Accuracy: 0.3284
# Train Epoch: 18 	Loss: 1.4552	Accuracy: 0.3294
# Train Epoch: 19 	Loss: 1.4536	Accuracy: 0.3303
# Train Epoch: 20 	Loss: 1.4521	Accuracy: 0.3312
# Train Epoch: 21 	Loss: 1.4507	Accuracy: 0.3320
# Train Epoch: 22 	Loss: 1.4491	Accuracy: 0.3328
# Train Epoch: 23 	Loss: 1.4480	Accuracy: 0.3333
# Train Epoch: 24 	Loss: 1.4468	Accuracy: 0.3339
# Train Epoch: 25 	Loss: 1.4455	Accuracy: 0.3348
# Train Epoch: 26 	Loss: 1.4442	Accuracy: 0.3356
# Train Epoch: 27 	Loss: 1.4430	Accuracy: 0.3364
# Train Epoch: 28 	Loss: 1.4419	Accuracy: 0.3372
# Train Epoch: 29 	Loss: 1.4408	Accuracy: 0.3380
# Train Epoch: 30 	Loss: 1.4397	Accuracy: 0.3390
# Train Epoch: 31 	Loss: 1.4387	Accuracy: 0.3396
# Train Epoch: 32 	Loss: 1.4375	Accuracy: 0.3405
# Train Epoch: 33 	Loss: 1.4365	Accuracy: 0.3413
# Train Epoch: 34 	Loss: 1.4354	Accuracy: 0.3422
# Train Epoch: 35 	Loss: 1.4343	Accuracy: 0.3433
# Train Epoch: 36 	Loss: 1.4333	Accuracy: 0.3442
# Train Epoch: 37 	Loss: 1.4322	Accuracy: 0.3451
# Train Epoch: 38 	Loss: 1.4312	Accuracy: 0.3459
# Train Epoch: 39 	Loss: 1.4303	Accuracy: 0.3466
# Train Epoch: 40 	Loss: 1.4294	Accuracy: 0.3475
# Train Epoch: 41 	Loss: 1.4284	Accuracy: 0.3484
# Train Epoch: 42 	Loss: 1.4274	Accuracy: 0.3493
# Train Epoch: 43 	Loss: 1.4264	Accuracy: 0.3503
# Train Epoch: 44 	Loss: 1.4253	Accuracy: 0.3512
# Train Epoch: 45 	Loss: 1.4244	Accuracy: 0.3521
# Train Epoch: 46 	Loss: 1.4234	Accuracy: 0.3529
# Train Epoch: 47 	Loss: 1.4224	Accuracy: 0.3539
# Train Epoch: 48 	Loss: 1.4214	Accuracy: 0.3548
# Train Epoch: 49 	Loss: 1.4204	Accuracy: 0.3557
# Test Epoch: 0 	Loss: 1.4196	Accuracy: 0.3405
# Test Epoch: 1 	Loss: 1.4139	Accuracy: 0.3536
# Test Epoch: 2 	Loss: 1.4110	Accuracy: 0.3599
# Test Epoch: 3 	Loss: 1.4093	Accuracy: 0.3623
# Test Epoch: 4 	Loss: 1.4073	Accuracy: 0.3663
# Test Epoch: 5 	Loss: 1.4053	Accuracy: 0.3677
# Test Epoch: 6 	Loss: 1.4037	Accuracy: 0.3695
# Test Epoch: 7 	Loss: 1.4024	Accuracy: 0.3709
# Test Epoch: 8 	Loss: 1.4012	Accuracy: 0.3728
# Test Epoch: 9 	Loss: 1.4001	Accuracy: 0.3735
# Test Epoch: 10 	Loss: 1.3989	Accuracy: 0.3747
# Test Epoch: 11 	Loss: 1.3979	Accuracy: 0.3757
# Test Epoch: 12 	Loss: 1.3968	Accuracy: 0.3771
# Test Epoch: 13 	Loss: 1.3959	Accuracy: 0.3778
# Test Epoch: 14 	Loss: 1.3949	Accuracy: 0.3787
# Test Epoch: 15 	Loss: 1.3936	Accuracy: 0.3802
# Test Epoch: 16 	Loss: 1.3925	Accuracy: 0.3813
# Test Epoch: 17 	Loss: 1.3916	Accuracy: 0.3823
# Test Epoch: 18 	Loss: 1.3907	Accuracy: 0.3829
# Test Epoch: 19 	Loss: 1.3895	Accuracy: 0.3841
# Test Epoch: 20 	Loss: 1.3887	Accuracy: 0.3850
# Test Epoch: 21 	Loss: 1.3878	Accuracy: 0.3860
# Test Epoch: 22 	Loss: 1.3870	Accuracy: 0.3870
# Test Epoch: 23 	Loss: 1.3859	Accuracy: 0.3881
# Test Epoch: 24 	Loss: 1.3851	Accuracy: 0.3891
# Test Epoch: 25 	Loss: 1.3841	Accuracy: 0.3902
# Test Epoch: 26 	Loss: 1.3833	Accuracy: 0.3912
# Test Epoch: 27 	Loss: 1.3824	Accuracy: 0.3921
# Test Epoch: 28 	Loss: 1.3813	Accuracy: 0.3931
# Test Epoch: 29 	Loss: 1.3803	Accuracy: 0.3943
# Test Epoch: 30 	Loss: 1.3796	Accuracy: 0.3950
# Test Epoch: 31 	Loss: 1.3787	Accuracy: 0.3959
# Test Epoch: 32 	Loss: 1.3779	Accuracy: 0.3969
# Test Epoch: 33 	Loss: 1.3770	Accuracy: 0.3977
# Test Epoch: 34 	Loss: 1.3760	Accuracy: 0.3987
# Test Epoch: 35 	Loss: 1.3751	Accuracy: 0.3995
# Test Epoch: 36 	Loss: 1.3741	Accuracy: 0.4006
# Test Epoch: 37 	Loss: 1.3733	Accuracy: 0.4014
# Test Epoch: 38 	Loss: 1.3724	Accuracy: 0.4023
# Test Epoch: 39 	Loss: 1.3714	Accuracy: 0.4033
# Test Epoch: 40 	Loss: 1.3705	Accuracy: 0.4043
# Test Epoch: 41 	Loss: 1.3696	Accuracy: 0.4050
# Test Epoch: 42 	Loss: 1.3686	Accuracy: 0.4060
# Test Epoch: 43 	Loss: 1.3676	Accuracy: 0.4070
# Test Epoch: 44 	Loss: 1.3667	Accuracy: 0.4080
# Test Epoch: 45 	Loss: 1.3660	Accuracy: 0.4086
# Test Epoch: 46 	Loss: 1.3652	Accuracy: 0.4095
# Test Epoch: 47 	Loss: 1.3643	Accuracy: 0.4106
# Test Epoch: 48 	Loss: 1.3634	Accuracy: 0.4115
# Test Epoch: 49 	Loss: 1.3625	Accuracy: 0.4125
